# %% [markdown]
# ## DATA ANALYSIS ##

# %%
import pandas as pd

df = pd.read_csv("payments.csv")

df.shape
# Out:
# (10000, 12)

# %%
df.head()
# Out:
#    customer_age  customer_tenure_months  payment_amount  \
# 0            56                      11         1505.74
# 1            69                      22         1557.84
# 2            46                      54          465.31
# 3            32                      24          721.96
# 4            60                       1          951.13
#
#    previous_payment_success_rate  previous_failed_payments  \
# 0                           0.49                         1
# 1                           0.53                         5
# 2                           0.89                         0
# 3                           0.84                         0
# 4                           0.52                         1
#
#    days_since_last_payment payment_method      failure_reason  \
# 0                       10            upi       card_declined
# 1                       86           card  insufficient_funds
# 2                       68            upi       network_error
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer_age                   10000 non-null  int64
#  1   customer_tenure_months         10000 non-null  int64
#  2   payment_amount                 10000 non-null  float64
#  3   previous_payment_success_rate  10000 non-null  float64
#  4   previous_failed_payments       10000 non-null  int64
#  5   days_since_last_payment        10000 non-null  int64
#  6   payment_method                 10000 non-null  str
#  7   failure_reason                 10000 non-null  str
#  8   subscription_age_months        10000 non-null  int64
#  9   customer_lifetime_value        10000 non-null  float64
#  10  previous_recovery_count        10000 non-null  int64
#  11  recovered                      10000 non-null  int64
# dtypes: float64(3), int64(7), str(2)
# ...

# %%
df["recovered"].value_counts()
# Out:
# recovered
# 1    7414
# 0    2586
# Name: count, dtype: int64

# %%
df["failure_reason"].value_counts()
# Out:
# failure_reason
# insufficient_funds    2992
# card_declined         2436
# bank_error            2071
# network_error         1519
# expired_card           982
# Name: count, dtype: int64
